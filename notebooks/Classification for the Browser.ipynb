# %% [markdown]
# ![profile.png](data:image/png;base64,...)

# %% [markdown]
# # Text Classification with Universal Sentence Encoder
#
# Our BERT and NNLM models perform really well when trained and tested in Google Colab - in this environment, we use a freely available GPU to speed up a set of otherwise computationally intensive processes.
#
# However, these larger models do not lend themselves to a browser-based implementation. Browser load time was significantly effected when loading a large model with hundreds of binary weight files.
#
# As a workaround, we use the lightweight universal sentence encoder for transfer learning. This model embeds our feature set into a smaller set of dimensions - this allows us to deploy a model to the browser with minimum concerns for runtime.
#
# ##### View this notebook in [Google Colab](https://drive.google.com/file/d/1xTnhAmy9KhNCQiy1ySZGKl56YEqCI-8M/view?usp=sharing)

# %% [markdown]
# # Import Resources
#
# Mount Google Drive and import required libaries - including `pandas` and `BeautifulSoup`.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
import pandas as pd
import re
from sklearn.preprocessing import LabelEncoder
import sklearn
import numpy as np
import os
import shutil

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

# A dependency of the preprocessing for BERT inputs
# !pip install -q tensorflow-text
# !pip install -q tf-models-official

import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_text as text
from official.nlp import optimization
from matplotlib import pyplot as plt
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#      |████████████████████████████████| 3.4MB 10.7MB/s
#      |████████████████████████████████| 1.1MB 15.1MB/s
#      |████████████████████████████████| 51kB 8.6MB/s
#      |████████████████████████████████| 102kB 13.2MB/s
#      |████████████████████████████████| 174kB 51.5MB/s
#      |████████████████████████████████| 1.2MB 54.4MB/s
#      |████████████████████████████████| 37.6MB 78kB/s
#      |████████████████████████████████| 645kB 53.1MB/s
#      |████████████████████████████████| 358kB 56.9MB/s
#      |████████████████████████████████| 706kB 55.5MB/s
#   Building wheel for seqeval (setup.py) ... done
#   Building wheel for py-cpuinfo (setup.py) ... done

# %% [markdown]
# # Import and Preprocess Training Data
#
# We first import our training data that was generated with our web scraping script. After the data is imported into this environment, we preprocess the records to get them ready for training and testing.

# %% [markdown]
# ### Data Import
#
# We use `pandas` to simply read in our data from Google Drive.

# %%
import tensorflow as tf
import pandas as pd

csv_file=tf.keras.utils.get_file(fname="/content/drive/MyDrive/coffee data/all_review_data.csv",origin="/content/drive/MyDrive/coffee data/all_review_data.csv")

df=pd.read_csv(csv_file)

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Generating Our Target Variable
#
# Our neural network will use a set of embeddings from tasting descriptions to predict what class of roast a particular coffee would likely fall into.We derive our target variable from the Agtron score - a value ranging from 25-80 that denotes the color of a coffee bean.
#
# For more information about Agtron scores, visit [CoffeeReview](https://www.coffeereview.com/coffee-reference/coffee-categories/roast-styles/roast-table/)
# or reference the tables below.

# %% [markdown]
# | Roast color | Bean surface | Agtron Numbers | Common names |
# |:-:|:-:|:-:|:-:|
# | Light brown | Dry | 80 – 70 | Light Cinnamon New England |
# | Medium brown | Dry | 70 – 50 | Medium American Regular City Brown |
# | Medium-dark brown | Dry to tiny droplets or patches of oil | 50 – 40 | Viennese Full-city Light French Espresso Light espresso Continental After-dinner European |
# | Dark brown | Shiny surface | 40-35 | French Espresso Italian Turkish Dark |
# | Very dark brown | Very shiny surface | 35-30 | Italian Dark French Neapolitan Spanish Heavy |
# | Black-brown | Shiny surface | 30-25 | Dark French Neapolitan Spanish |

# %% [markdown]
# | Agtron Numbers | Notes |
# |:-:|:-:|
# | 80 – 70 | Can taste sour and grainy. Typically used only for inexpensive commercial blends. |
# | 70 – 50 | The traditional American norm. Flavor is fully developed; acidity is bright; characteristics of green coffee are clear. |
# | 50 – 40 | The normal or regular roast for the West and for many newer specialty roasters. Acidity and the characteristics of the green coffee begin to mute. Bittersweetness emerges. The norm for northern-Italian style espresso. |
# | 40-35 | The normal or regular roast for many roasters in the West and Southwest. Acidity is nearly gone; the characteristics of the green coffee muted. Bittersweet tones dominate. The norm for most American-style espresso. |
# | 35-30 | The normal or regular roast for Peet’s Coffee and its imitators. Acidity is gone. In tactful versions of this roast some characteristics of the green coffee survive; in aggressive versions all coffees taste the same: bittersweet with hints of burned or charred tones. |
# | 30-25 | All differentiating characteristics of the green coffee are gone; burned or charred notes dominate. Body is thin. Flavor is reduced to faint sweet tones. |

# %%
# Split Agtron Score - 
df[['Agrtron_Bean','Agtron_Ground']] = df.Agtron.str.split('/',expand=True) 

# Remove Null Values
df=df[~df['Agrtron_Bean'].isnull()]
df=df[df['Agrtron_Bean']!='NA']
df=df[df['Agrtron_Bean']!='']

# Replace Likely Fat Fingered Scores
df['Agrtron_Bean']=df['Agrtron_Bean'].replace('547','54')
df['Agrtron_Bean']=df['Agrtron_Bean'].replace('555','55')

# Push Target Variable to Float
df['Agrtron_Bean']=df['Agrtron_Bean'].astype(float)

# Bucketize Target Variable into 6 Classess
df['class'] = pd.cut(df['Agrtron_Bean'], [25,30,35,40,50,70,80], labels=['BlackBrown','VeryDarkBrown','DarkBrown','MediumDarkBrown','MediumBrown','LightBrown'])

# Remove Records with No Class
df=df[~df['class'].isna()]

# %%
# Preview of Our Data

print ("Here is our raw data:")
df.head(5)
# Out:
# Here is our raw data:
#    Unnamed: 0  score  ... Agtron_Ground        class
# 0           0     95  ...            72  MediumBrown
# 1           1     94  ...            72  MediumBrown
# 2           2     94  ...            80  MediumBrown
# 3           3     93  ...            68  MediumBrown
# 4           4     94  ...            70  MediumBrown
#
# [5 rows x 15 columns]

# %% [markdown]
# ### Generate Our Feature Variable
#
# Our neural network will use a set of embeddings from tasting descriptions to predict what class of roast a particular coffee would likely fall into. Our feature column is a concatenation of three free-text fields that are typical for a coffee review - blind assessment, tasting notes, and bottom line.
#
# The code below prepeares our feature column for Tensorflow. We concatenate our
# text fields, remove HTML tags, strip stopwords, and downsize our dataframe to our two columns of interest - target and feature.

# %%
# Generate our feature column - combining three text fields into a single string per review/record.
df['bottom_line']=df['bottom_line'].fillna('')
df['notes']=df['notes'].fillna('')
df['blind_assessment']=df['blind_assessment'].fillna('')

df['text']=df['bottom_line']+' '+df['notes']+' '+df['blind_assessment']

# Define Our Stopwords with NLTK
# Our word embedding layer likely removes stopwords, but we remove them in our preprocessing stage for peace of mind.
stop = stopwords.words('english')

df['text']= df['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))

# Remove HTML tags from our free-text field
def remove_tags(string):
    result = re.sub('<.*?>','',string)
    return result

df['text']=df['text'].apply(lambda cw : remove_tags(cw))

# Subset our dataframe to our two columns of interest

df=df[['class','text']]

# %%
# Preview of Our Data

print ("Here is our data after some initial preprocessing:")
df.head(5)
# Out:
# Here is our data after some initial preprocessing:
#          class                                               text
# 0  MediumBrown  Richly spice-toned, floral- fruit-driven, comp...
# 1  MediumBrown  An impressive, affordably priced single-origin...
# 2  MediumBrown  A balanced, juicy washed Ethiopia cup driven n...
# 3  MediumBrown  A resonant Peru cup notes deep florals, stone ...
# 4  MediumBrown  A deep, brooding, balanced Panama Pacamara cup...

# %% [markdown]
# ### Encode our Target Variable
#
# Tensorflow operates under the assumption that it's inputs,intermediary layers, and outputs are all tensors or vectors with some arbitrary dimension.
#
# We use `sklearn.preprocessing.LabelEncoder` to encoder our target labels with value between 0 and n_classes-1.

# %%
# Encoding
encoder = LabelEncoder()
df['class2'] = encoder.fit_transform(df['class'])

# Store Our Class Mappings for Reference Later
class_mapping=df[['class','class2']]

# Subset our dataframe to our two columns of interest
df=df[['text','class2']]

# %%
# Preview of Our Data

print ("Here is our data after encoding our target value:")
df.head(5)
# Out:
# Here is our data after encoding our target value:
#                                                 text  class2
# 0  Richly spice-toned, floral- fruit-driven, comp...       3
# 1  An impressive, affordably priced single-origin...       3
# 2  A balanced, juicy washed Ethiopia cup driven n...       3
# 3  A resonant Peru cup notes deep florals, stone ...       3
# 4  A deep, brooding, balanced Panama Pacamara cup...       3

# %% [markdown]
# # Model Architecture and Design

# %% [markdown]
# ### Download and Instantiate Lightweight Universal Sentence Encoder from Tensorflow Hub

# %%
embed = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")

# %% [markdown]
# ### Model Data
#
# We create and execute a function to generate our training and test data.

# %%
train_examples,train_labels=np.array(df['text']),np.array(df['class2'])

def train_test_split(x,y,split):

  x, y = sklearn.utils.shuffle(x, y)

  split_int=int(len(train_examples)*split)

  x_val = x[split_int:]
  partial_x_train = x[:split_int]

  y_val = y[split_int:]
  partial_y_train = y[:split_int]

  x_val,partial_x_train= embed(x_val),embed(partial_x_train)
  return (partial_x_train,partial_y_train,x_val,y_val)

x_train,y_train,x_test,y_test=train_test_split(train_examples,train_labels,0.95)

# %% [markdown]
# ### Model Design
#
# We build a neural network with the Keras Layers API. Our input layer is passed thru an encoding layer that transforms our feature field into an n-dimensional space. Those encodings work thru a series of layers. The final output is a softmax layer - providing us with a probability distribution of our input layer falling into each of our six categories.

# %%
model = tf.keras.models.Sequential([
        tf.keras.layers.Input(shape=x_train[0].shape),
        tf.keras.layers.Reshape((4,128)),
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64,
                   activation='tanh',
                   dropout=0.2,
                   recurrent_dropout=0.5,return_sequences=True)),
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64)),
        #tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(len(np.unique(df['class2'])), activation='softmax')
])

model.summary()
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape (Reshape)            (None, 4, 128)            0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 4, 128)            98816
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 128)               98816
# _________________________________________________________________
# dense (Dense)                (None, 64)                8256
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 390
# =================================================================
# Total params: 206,278
# Trainable params: 206,278
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Model Compilation
#
# We compile our model using the Adam optimizer and the Sparse Categorical Crossentropy loss function. If our target value was one-hot enoded, we could use
# Categorical Crossentropy.

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01/10),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %% [markdown]
# ### Model Fitting
#
# We train the model for fifty epochs and a batch size of ten as a proof of concept. This model beings to perform incredibly well when trained with a properly
# configured batch size.
#
# However, that process is too time-intensive for the purposes of this demo.
#
# Feel free to play with the hyperparamters below!

# %%
history = model.fit(x_train,
                    y_train,
                    epochs=50,
                    batch_size=10,
                    validation_data=(x_test, y_test),
                    verbose=1)
                    ##callbacks=[tensorboard_callback])
# Out:
# Epoch 1/50
# 453/453 [==============================] - 46s 33ms/step - loss: 1.0606 - accuracy: 0.6259 - val_loss: 0.8299 - val_accuracy: 0.6820
# Epoch 2/50
# 453/453 [==============================] - 13s 29ms/step - loss: 0.8072 - accuracy: 0.6727 - val_loss: 0.7946 - val_accuracy: 0.6862
# Epoch 3/50
# 453/453 [==============================] - 13s 29ms/step - loss: 0.7975 - accuracy: 0.6830 - val_loss: 0.7906 - val_accuracy: 0.6946
# Epoch 4/50
# 453/453 [==============================] - 14s 30ms/step - loss: 0.7819 - accuracy: 0.6939 - val_loss: 0.7752 - val_accuracy: 0.6904
# Epoch 5/50
# 453/453 [==============================] - 14s 30ms/step - loss: 0.7920 - accuracy: 0.6859 - val_loss: 0.7911 - val_accuracy: 0.6778
# Epoch 6/50
# 453/453 [==============================] - 13s 29ms/step - loss: 0.7492 - accuracy: 0.7113 - val_loss: 0.7669 - val_accuracy: 0.7113
# Epoch 7/50
# 453/453 [==============================] - 13s 30ms/step - loss: 0.7456 - accuracy: 0.6953 - val_loss: 0.7799 - val_accuracy: 0.6946
# Epoch 8/50
# 453/453 [==============================] - 13s 30ms/step - loss: 0.7495 - accuracy: 0.7004 - val_loss: 0.7717 - val_accuracy: 0.6862
# Epoch 9/50
# 453/453 [==============================] - 13s 29ms/step - loss: 0.7538 - accuracy: 0.6962 - val_loss: 0.7819 - val_accuracy: 0.7029
# Epoch 10/50
# 453/453 [==============================] - 13s 29ms/step - loss: 0.7343 - accuracy: 0.7015 - val_loss: 0.7693 - val_accuracy: 0.7071
# Epoch 11/50
# 453/453 [==============================] - 13s 30ms/step - loss: 0.7267 - accuracy: 0.7034 - val_loss: 0.7727 - val_accuracy: 0.7197
# Epoch 12/50
# 453/453 [==============================] - 13s 29ms/step - loss: 0.7419 - accuracy: 0.6995 - val_loss: 0.7628 - val_accuracy: 0.7113
# Epoch 13/50
# 453/453 [==============================] - 13s 30ms/step - loss: 0.7124 - accuracy: 0.7141 - val_loss: 0.7696 - val_accuracy: 0.6778
# Epoch 14/50
# 453/453 [==============================] - 13s 29ms/step - loss: 0.7425 - accuracy: 0.6904 - val_loss: 0.7832 - val_accuracy: 0.7113
# Epoch 15/50
# 453/453 [==============================] - 13s 29ms/step - loss: 0.7201 - accuracy: 0.7131 - val_loss: 0.7778 - val_accuracy: 0.6987
# Epoch 16/50
# 453/453 [==============================] - 13s 29ms/step - loss: 0.7458 - accuracy: 0.6973 - val_loss: 0.7685 - val_accuracy: 0.7071
# Epoch 17/50
# 453/453 [==============================] - 14s 30ms/step - loss: 0.7221 - accuracy: 0.6996 - val_loss: 0.7483 - val_accuracy: 0.7113
# Epoch 18/50
# 453/453 [==============================] - 14s 30ms/step - loss: 0.6865 - accuracy: 0.7296 - val_loss: 0.7624 - val_accuracy: 0.7113
# Epoch 19/50
# 453/453 [==============================] - 13s 29ms/step - loss: 0.7007 - accuracy: 0.7116 - val_loss: 0.7742 - val_accuracy: 0.7071
# Epoch 20/50
# 453/453 [==============================] - 14s 30ms/step - loss: 0.7127 - accuracy: 0.7055 - val_loss: 0.7668 - val_accuracy: 0.6820
# Epoch 21/50
# 453/453 [==============================] - 13s 29ms/step - loss: 0.6833 - accuracy: 0.7193 - val_loss: 0.7967 - val_accuracy: 0.6695
# Epoch 22/50
# 453/453 [==============================] - 13s 29ms/step - loss: 0.6939 - accuracy: 0.7093 - val_loss: 0.7641 - val_accuracy: 0.6946
# Epoch 23/50
# 453/453 [==============================] - 14s 30ms/step - loss: 0.6824 - accuracy: 0.7120 - val_loss: 0.7625 - val_accuracy: 0.7029
# Epoch 24/50
# 453/453 [==============================] - 14s 30ms/step - loss: 0.7075 - accuracy: 0.7049 - val_loss: 0.7702 - val_accuracy: 0.7155
# Epoch 25/50
# 453/453 [==============================] - 13s 29ms/step - loss: 0.6834 - accuracy: 0.7133 - val_loss: 0.7678 - val_accuracy: 0.7029
# Epoch 26/50
# 453/453 [==============================] - 13s 30ms/step - loss: 0.6645 - accuracy: 0.7230 - val_loss: 0.7860 - val_accuracy: 0.6904
# Epoch 27/50
# 453/453 [==============================] - 13s 29ms/step - loss: 0.6874 - accuracy: 0.7180 - val_loss: 0.7728 - val_accuracy: 0.7029
# Epoch 28/50
# 453/453 [==============================] - 13s 29ms/step - loss: 0.6744 - accuracy: 0.7189 - val_loss: 0.7573 - val_accuracy: 0.6862
# Epoch 29/50
# 453/453 [==============================] - 13s 29ms/step - loss: 0.6600 - accuracy: 0.7210 - val_loss: 0.7606 - val_accuracy: 0.6862
# Epoch 30/50
# 453/453 [==============================] - 13s 29ms/step - loss: 0.6764 - accuracy: 0.7178 - val_loss: 0.7763 - val_accuracy: 0.7029
# Epoch 31/50
# 453/453 [==============================] - 13s 30ms/step - loss: 0.6604 - accuracy: 0.7272 - val_loss: 0.7738 - val_accuracy: 0.6946
# Epoch 32/50
# 453/453 [==============================] - 13s 29ms/step - loss: 0.6398 - accuracy: 0.7363 - val_loss: 0.7755 - val_accuracy: 0.6862
# Epoch 33/50
# 453/453 [==============================] - 14s 30ms/step - loss: 0.6416 - accuracy: 0.7292 - val_loss: 0.7763 - val_accuracy: 0.7029
# Epoch 34/50
# 453/453 [==============================] - 13s 29ms/step - loss: 0.6502 - accuracy: 0.7323 - val_loss: 0.8128 - val_accuracy: 0.7155
# Epoch 35/50
# 453/453 [==============================] - 13s 29ms/step - loss: 0.6386 - accuracy: 0.7349 - val_loss: 0.7565 - val_accuracy: 0.7197
# Epoch 36/50
# 453/453 [==============================] - 13s 30ms/step - loss: 0.6454 - accuracy: 0.7301 - val_loss: 0.7561 - val_accuracy: 0.7155
# Epoch 37/50
# 453/453 [==============================] - 13s 29ms/step - loss: 0.6336 - accuracy: 0.7342 - val_loss: 0.7590 - val_accuracy: 0.7155
# Epoch 38/50
# 453/453 [==============================] - 14s 30ms/step - loss: 0.6264 - accuracy: 0.7353 - val_loss: 0.7587 - val_accuracy: 0.6946
# Epoch 39/50
# 453/453 [==============================] - 13s 30ms/step - loss: 0.5952 - accuracy: 0.7590 - val_loss: 0.7567 - val_accuracy: 0.7071
# Epoch 40/50
# 453/453 [==============================] - 13s 30ms/step - loss: 0.5967 - accuracy: 0.7480 - val_loss: 0.7642 - val_accuracy: 0.6904
# Epoch 41/50
# 453/453 [==============================] - 13s 30ms/step - loss: 0.5938 - accuracy: 0.7552 - val_loss: 0.7673 - val_accuracy: 0.7029
# Epoch 42/50
# 453/453 [==============================] - 13s 29ms/step - loss: 0.6010 - accuracy: 0.7517 - val_loss: 0.7430 - val_accuracy: 0.7197
# Epoch 43/50
# 453/453 [==============================] - 13s 30ms/step - loss: 0.6036 - accuracy: 0.7462 - val_loss: 0.7604 - val_accuracy: 0.7113
# Epoch 44/50
# 453/453 [==============================] - 13s 29ms/step - loss: 0.5958 - accuracy: 0.7507 - val_loss: 0.7824 - val_accuracy: 0.6946
# Epoch 45/50
# 453/453 [==============================] - 14s 30ms/step - loss: 0.5828 - accuracy: 0.7607 - val_loss: 0.7651 - val_accuracy: 0.7113
# Epoch 46/50
# 453/453 [==============================] - 13s 29ms/step - loss: 0.5982 - accuracy: 0.7565 - val_loss: 0.8058 - val_accuracy: 0.6946
# Epoch 47/50
# 453/453 [==============================] - 13s 30ms/step - loss: 0.5659 - accuracy: 0.7648 - val_loss: 0.7835 - val_accuracy: 0.7155
# Epoch 48/50
# 453/453 [==============================] - 13s 30ms/step - loss: 0.5766 - accuracy: 0.7593 - val_loss: 0.7552 - val_accuracy: 0.7155
# Epoch 49/50
# 453/453 [==============================] - 13s 29ms/step - loss: 0.5585 - accuracy: 0.7645 - val_loss: 0.7709 - val_accuracy: 0.7155
# Epoch 50/50
# 453/453 [==============================] - 13s 30ms/step - loss: 0.5603 - accuracy: 0.7703 - val_loss: 0.7870 - val_accuracy: 0.7071

# %% [markdown]
# ### Model Review

# %%
def display_training_curves(training, validation, title, subplot):
  if subplot%10==1: # set up the subplots on the first call
    plt.subplots(figsize=(10,10), facecolor='#F0F0F0')
    plt.tight_layout()
  ax = plt.subplot(subplot)
  ax.set_facecolor('#F8F8F8')
  ax.plot(training)
  ax.plot(validation)
  ax.set_title('model '+ title)
  ax.set_ylabel(title)
  ax.set_xlabel('epoch')
  ax.legend(['train', 'valid.'])

display_training_curves(history.history['accuracy'], history.history['val_accuracy'], 'accuracy', 211)
display_training_curves(history.history['loss'], history.history['val_loss'], 'loss', 212)

# %% [markdown]
# ### Model Evaulation

# %%
results = model.evaluate(x_test,y_test)

print(results)
# Out:
# 8/8 [==============================] - 0s 4ms/step - loss: 0.7870 - accuracy: 0.7071
# [0.7869589924812317, 0.7071129679679871]

# %% [markdown]
# ### Model Prediction

# %%
my_coffee_review= '''I love a dark espresso that is rich and full bodied. Starbucks does a good espresso 
and I think that would probably be my favorite cup of coffee.'''

predictions = model(tf.constant(embed([my_coffee_review])))
print(tf.sigmoid(predictions))
# Out:
# tf.Tensor([[0.50004447 0.5289486  0.5000002  0.5526181  0.59971243 0.566694  ]], shape=(1, 6), dtype=float32)

# %% [markdown]
# ### Model Export

# %%
saved_model_path = "/content/drive/MyDrive/coffee-mate/model/my_model.h5"

model.save(saved_model_path)
