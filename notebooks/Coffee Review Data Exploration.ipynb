# %% [markdown]
# ![profile.png](data:image/png;base64,...)

# %% [markdown]
# # Data Exploration with Pandas
#
# Explore the data collected from [Coffee Review](https://www.coffeereview.com/), create your own model, or derive some interesting insights!
#
# ##### View this notebook in [Google Colab](https://drive.google.com/file/d/191H_pikIrJYUiautd5JjsfisZU00eDHW/view?usp=sharing)

# %%
import pandas as pd

df= pd.read_csv('https://raw.githubusercontent.com/kcarrig/coffee-mate/main/data/all_review_data.csv')

df.columns=['index','score','roaster',
                        'title','Roaster Location','Coffee Origin',
                        'Roast Level','Agtron','Est. Price','blind_assessment',
                        'notes','bottom_line']

df.head(5)
# Out:
#    index  ...                                        bottom_line
# 0      0  ...  Richly spice-toned, floral- and fruit-driven, ...
# 1      1  ...  An impressive, affordably priced single-origin...
# 2      2  ...  A balanced, juicy washed Ethiopia cup driven b...
# 3      3  ...  A resonant Peru cup with notes of deep florals...
# 4      4  ...  A deep, brooding, balanced Panama Pacamara cup...
#
# [5 rows x 12 columns]
